# %%
import os
from pprint import pprint

import numpy as np
import pandas as pd

from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)

from imblearn.under_sampling import RandomUnderSampler

from tqdm import tqdm

# %%
ROOT_DIR = "data"
RANDOM_STATE = 110

# Load data
df_train = pd.read_csv(os.path.join(ROOT_DIR, "train.csv"))
df_train
# Out:
#       Wip Line_Dam Process Desc._Dam     Equipment_Dam Model.Suffix_Dam  \
# 0          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334505
# 1          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334505
# 2          IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 3          IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 4          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# ...            ...               ...               ...              ...
# 40501      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# 40502      IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 40503      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# 40504      IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 40505      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
#
#       Workorder_Dam  Insp. Seq No._Dam Insp Judge Code_Dam  \
# 0        4F1XA938-1                  1                  OK
# 1        3KPM0016-2                  1                  OK
# 2        4E1X9167-1                  1                  OK
# 3        3K1X0057-1                  1                  OK
# 4        3HPM0007-1                  1                  OK
# ...             ...                ...                 ...
# 40501    3J1XF434-2                  1                  OK
# 40502    4E1XC796-1                  1                  OK
# 40503    4C1XD438-1                  1                  OK
# 40504    3I1XA258-1                  1                  OK
# 40505    3G1XA501-1                  1                  OK
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION X Unit Time_Dam  CURE END POSITION X Judge Value_Dam  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 40501                                NaN                                  NaN
# 40502                                NaN                                  NaN
# 40503                                NaN                                  NaN
# 40504                                NaN                                  NaN
# 40505                                NaN                                  NaN
#
#        ...  Production Qty Collect Result_Fill2  \
# 0      ...                                    7
# 1      ...                                  185
# 2      ...                                   10
# 3      ...                                  268
# 4      ...                                  121
# ...    ...                                  ...
# 40501  ...                                  318
# 40502  ...                                   14
# 40503  ...                                    1
# 40504  ...                                  117
# 40505  ...                                  320
#
#        Production Qty Unit Time_Fill2  Production Qty Judge Value_Fill2  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 40501                             NaN                               NaN
# 40502                             NaN                               NaN
# 40503                             NaN                               NaN
# 40504                             NaN                               NaN
# 40505                             NaN                               NaN
#
#        Receip No Collect Result_Fill2  Receip No Unit Time_Fill2  \
# 0                                 127                        NaN
# 1                                   1                        NaN
# 2                                  73                        NaN
# 3                                   1                        NaN
# 4                                   1                        NaN
# ...                               ...                        ...
# 40501                               1                        NaN
# 40502                             197                        NaN
# 40503                              27                        NaN
# 40504                               1                        NaN
# 40505                               1                        NaN
#
#        Receip No Judge Value_Fill2  WorkMode Collect Result_Fill2  \
# 0                              NaN                              1
# 1                              NaN                              0
# 2                              NaN                              1
# 3                              NaN                              0
# 4                              NaN                              0
# ...                            ...                            ...
# 40501                          NaN                              0
# 40502                          NaN                              1
# 40503                          NaN                              1
# 40504                          NaN                              0
# 40505                          NaN                              0
#
#        WorkMode Unit Time_Fill2  WorkMode Judge Value_Fill2    target
# 0                           NaN                         NaN    Normal
# 1                           NaN                         NaN    Normal
# 2                           NaN                         NaN    Normal
# 3                           NaN                         NaN    Normal
# 4                           NaN                         NaN    Normal
# ...                         ...                         ...       ...
# 40501                       NaN                         NaN    Normal
# 40502                       NaN                         NaN    Normal
# 40503                       NaN                         NaN    Normal
# 40504                       NaN                         NaN    Normal
# 40505                       NaN                         NaN  AbNormal
#
# [40506 rows x 464 columns]

# %%
# 타겟 변수 인코딩
df_train['target_encoded'] = df_train['target'].apply(lambda x: 1 if x == 'AbNormal' else 0)

# %%
# 모든 피처 사용
all_features = df_train.drop(columns=['target', 'target_encoded']).columns

# %%
# X와 y 정의
X = df_train[all_features]
y = df_train['target_encoded']

# %%
# 범주형 및 수치형 피처 분리
categorical_features = X.select_dtypes(include=['object']).columns
numeric_features = X.select_dtypes(exclude=['object']).columns

# %%
# 파이프라인 구성 (수치형: 표준화, 범주형: One-Hot 인코딩)
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),  # 결측값 처리
    ('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),  # 결측값 처리
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
# ColumnTransformer를 통해 수치형 및 범주형 피처를 변환
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
# # 데이터를 전처리 (One-Hot 인코딩 및 표준화 적용)
# X_processed = preprocessor.fit_transform(X)

# %%
# # TruncatedSVD 적용 (다양한 n_components 값에 대해 분산 비율 계산)
# explained_variance_ratios = []
# components_range = range(1, min(300, X_processed.shape[1] + 1), 10)  # 10단위로 최대 300까지 테스트

# for n in components_range:
#     svd = TruncatedSVD(n_components=n, random_state=42)
#     svd.fit(X_processed)
#     explained_variance_ratios.append(svd.explained_variance_ratio_.sum())

# %%
# # 결과 시각화
# import matplotlib.pyplot as plt

# plt.figure(figsize=(10, 6))
# plt.plot(components_range, explained_variance_ratios, marker='o')
# plt.title('Explained Variance Ratio by Number of Components')
# plt.xlabel('Number of Components')
# plt.ylabel('Explained Variance Ratio')
# plt.grid(True)
# plt.show()

# %%
# TruncatedSVD 구성
svd = TruncatedSVD(n_components=50)  # 사용할 주성분 개수 설정 (조정 가능)

# %%
# SVM 모델용 파이프라인 구성
svm_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),  # 전처리 (표준화 및 One-Hot 인코딩)
    ('svd', TruncatedSVD(n_components=50, random_state=42)),  # 차원 축소
    ('classifier', SVC(kernel='rbf', class_weight='balanced', random_state=42))  # SVM 모델
])

# %%
# 데이터 분할 (학습용: 80%, 테스트용: 20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
# 언더샘플링을 통해 다수 클래스의 수를 줄임
rus = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = rus.fit_resample(X_train, y_train)

# %%
# StratifiedKFold 설정 (과적합 방지를 위한 폴드 설정)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
# GridSearchCV 설정
param_grid = {
    'classifier__C': [0.1, 1, 10, 100],  # 파이프라인 내 SVM 모델의 하이퍼파라미터 설정
    'classifier__gamma': [1, 0.1, 0.01, 0.001],
}

# %%
grid_search = GridSearchCV(svm_pipeline, param_grid, cv=skf, scoring='f1', n_jobs=-1, verbose=3)
grid_search.fit(X_resampled, y_resampled)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          Index(['Insp. Seq No._Dam', 'CURE END POSITION X Collect Result_Dam',
#        'CURE END POSITION X Unit Time_Dam',
#        'CURE END POSIT...
#        'HEAD NORMAL COORDINATE X AXIS(Stage1) Collect Result_Fill2',
#        'HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Fill2'],
#       dtype='object'))])),
#                                        ('svd',
#                                         TruncatedSVD(n_components=50,
#                                                      random_state=42)),
#                                        ('classifier',
#                                         SVC(class_weight='balanced',
#                                             random_state=42))]),
#              n_jobs=-1,
#              param_grid={'classifier__C': [0.1, 1, 10, 100],
#                          'classifier__gamma': [1, 0.1, 0.01, 0.001]},
#              scoring='f1', verbose=3)

# %%
# 최적의 하이퍼파라미터 출력
print(f"Best parameters: {grid_search.best_params_}")
# Out:
# Best parameters: {'classifier__C': 100, 'classifier__gamma': 0.001}

# %%
# 최적의 모델로 예측 수행
best_svm_model = grid_search.best_estimator_
y_pred = best_svm_model.predict(X_test)

# %%
# 성능 평가
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.64      0.77     11447
#            1       0.08      0.54      0.15       705
#
#     accuracy                           0.63     12152
#    macro avg       0.52      0.59      0.46     12152
# weighted avg       0.91      0.63      0.73     12152
#
# [[7322 4125]
#  [ 322  383]]

# %%
df_test = pd.read_csv(os.path.join(ROOT_DIR, "test.csv"))

# %%
# 모든 피처 사용
X_test = df_test[all_features]

# %%
test_pred = best_svm_model.predict(X_test)

# %%
test_pred_labels = ['AbNormal' if y == 1 else 'Normal' for y in test_pred]

test_pred_labels
# Out:
# ['AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  'AbNormal',
#  'Normal',
#  'AbNormal',
#  'AbNormal',
#  ...]

# %%
test_pred_series = pd.Series(test_pred_labels)
count_labels = test_pred_series.value_counts()

print(count_labels)
# Out:
# Normal      10844
# AbNormal     6517
# Name: count, dtype: int64

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["target"] = test_pred_labels

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)
# Out:
# [CV 4/5] END classifier__C=0.1, classifier__gamma=1;, score=0.115 total time=   1.7s
# [CV 5/5] END classifier__C=0.1, classifier__gamma=1;, score=0.127 total time=   1.7s
# [CV 2/5] END classifier__C=0.1, classifier__gamma=0.01;, score=0.147 total time=   1.6s
# [CV 1/5] END classifier__C=0.1, classifier__gamma=0.001;, score=0.112 total time=   1.6s
# [CV 5/5] END classifier__C=0.1, classifier__gamma=0.001;, score=0.138 total time=   1.6s
# [CV 4/5] END classifier__C=1, classifier__gamma=1;, score=0.167 total time=   1.6s
# [CV 3/5] END classifier__C=1, classifier__gamma=0.1;, score=0.094 total time=   1.2s
# [CV 1/5] END classifier__C=1, classifier__gamma=0.01;, score=0.108 total time=   1.5s
# [CV 5/5] END classifier__C=1, classifier__gamma=0.01;, score=0.120 total time=   1.5s
# [CV 4/5] END classifier__C=1, classifier__gamma=0.001;, score=0.110 total time=   1.6s
# [CV 3/5] END classifier__C=10, classifier__gamma=1;, score=0.113 total time=   1.6s
# [CV 2/5] END classifier__C=10, classifier__gamma=0.1;, score=0.115 total time=   1.0s
# [CV 5/5] END classifier__C=10, classifier__gamma=0.1;, score=0.127 total time=   1.0s
# [CV 4/5] END classifier__C=10, classifier__gamma=0.01;, score=0.112 total time=   1.3s
# [CV 3/5] END classifier__C=10, classifier__gamma=0.001;, score=0.108 total time=   1.5s
# [CV 2/5] END classifier__C=100, classifier__gamma=1;, score=0.147 total time=   1.7s
# [CV 1/5] END classifier__C=100, classifier__gamma=0.1;, score=0.109 total time=   1.0s
# [CV 4/5] END classifier__C=100, classifier__gamma=0.1;, score=0.144 total time=   1.0s
# [CV 3/5] END classifier__C=100, classifier__gamma=0.01;, score=0.076 total time=   1.2s
# [CV 2/5] END classifier__C=100, classifier__gamma=0.001;, score=0.112 total time=   1.5s
# [CV 1/5] END classifier__C=0.1, classifier__gamma=1;, score=0.042 total time=   1.4s
# [CV 5/5] END classifier__C=0.1, classifier__gamma=1;, score=0.042 total time=   1.2s
# [CV 4/5] END classifier__C=0.1, classifier__gamma=0.1;, score=0.571 total time=   1.2s
# [CV 3/5] END classifier__C=0.1, classifier__gamma=0.01;, score=0.514 total time=   1.2s
# [CV 2/5] END classifier__C=0.1, classifier__gamma=0.001;, score=0.553 total time=   1.2s
# [CV 1/5] END classifier__C=1, classifier__gamma=1;, score=0.530 total time=   1.2s
# [CV 5/5] END classifier__C=1, classifier__gamma=1;, score=0.547 total time=   1.3s
# [CV 4/5] END classifier__C=1, classifier__gamma=0.1;, score=0.574 total time=   1.2s
# [CV 3/5] END classifier__C=1, classifier__gamma=0.01;, score=0.576 total time=   1.2s
# [CV 2/5] END classifier__C=1, classifier__gamma=0.001;, score=0.537 total time=   1.2s
# [CV 1/5] END classifier__C=10, classifier__gamma=1;, score=0.528 total time=   1.4s
# [CV 5/5] END classifier__C=10, classifier__gamma=1;, score=0.548 total time=   1.3s
# [CV 4/5] END classifier__C=10, classifier__gamma=0.1;, score=0.587 total time=   1.2s
# [CV 3/5] END classifier__C=10, classifier__gamma=0.01;, score=0.602 total time=   1.2s
# [CV 2/5] END classifier__C=10, classifier__gamma=0.001;, score=0.550 total time=   1.2s
# [CV 1/5] END classifier__C=100, classifier__gamma=1;, score=0.527 total time=   1.4s
# [CV 5/5] END classifier__C=100, classifier__gamma=1;, score=0.545 total time=   1.3s
# [CV 4/5] END classifier__C=100, classifier__gamma=0.1;, score=0.571 total time=   1.7s
# [CV 3/5] END classifier__C=100, classifier__gamma=0.01;, score=0.564 total time=   1.3s
# [CV 2/5] END classifier__C=100, classifier__gamma=0.001;, score=0.588 total time=   1.2s
# [CV 3/5] END classifier__C=0.1, classifier__gamma=1;, score=0.066 total time=   1.7s
# [CV 2/5] END classifier__C=0.1, classifier__gamma=0.1;, score=0.119 total time=   1.6s
# [CV 5/5] END classifier__C=0.1, classifier__gamma=0.1;, score=0.115 total time=   1.6s
# [CV 4/5] END classifier__C=0.1, classifier__gamma=0.01;, score=0.094 total time=   1.5s
# [CV 2/5] END classifier__C=0.1, classifier__gamma=0.001;, score=0.160 total time=   1.6s
# [CV 1/5] END classifier__C=1, classifier__gamma=1;, score=0.146 total time=   1.6s
# [CV 5/5] END classifier__C=1, classifier__gamma=1;, score=0.127 total time=   1.5s
# [CV 2/5] END classifier__C=1, classifier__gamma=0.01;, score=0.133 total time=   1.5s
# [CV 1/5] END classifier__C=1, classifier__gamma=0.001;, score=0.133 total time=   1.5s
# [CV 5/5] END classifier__C=1, classifier__gamma=0.001;, score=0.184 total time=   1.6s
# [CV 4/5] END classifier__C=10, classifier__gamma=1;, score=0.164 total time=   1.5s
# [CV 3/5] END classifier__C=10, classifier__gamma=0.1;, score=0.106 total time=   1.0s
# [CV 1/5] END classifier__C=10, classifier__gamma=0.01;, score=0.113 total time=   1.3s
# [CV 5/5] END classifier__C=10, classifier__gamma=0.01;, score=0.124 total time=   1.3s
# [CV 4/5] END classifier__C=10, classifier__gamma=0.001;, score=0.118 total time=   1.5s
# [CV 3/5] END classifier__C=100, classifier__gamma=1;, score=0.111 total time=   1.5s
# [CV 2/5] END classifier__C=100, classifier__gamma=0.1;, score=0.110 total time=   1.0s
# [CV 5/5] END classifier__C=100, classifier__gamma=0.1;, score=0.140 total time=   1.0s
# [CV 4/5] END classifier__C=100, classifier__gamma=0.01;, score=0.119 total time=   1.3s
# [CV 3/5] END classifier__C=100, classifier__gamma=0.001;, score=0.119 total time=   1.4s
# [CV 2/5] END classifier__C=0.1, classifier__gamma=1;, score=0.042 total time=   1.5s
# [CV 2/5] END classifier__C=0.1, classifier__gamma=0.1;, score=0.573 total time=   1.2s
# [CV 1/5] END classifier__C=0.1, classifier__gamma=0.01;, score=0.509 total time=   1.2s
# [CV 5/5] END classifier__C=0.1, classifier__gamma=0.01;, score=0.528 total time=   1.2s
# [CV 4/5] END classifier__C=0.1, classifier__gamma=0.001;, score=0.561 total time=   1.2s
# [CV 3/5] END classifier__C=1, classifier__gamma=1;, score=0.511 total time=   1.3s
# [CV 2/5] END classifier__C=1, classifier__gamma=0.1;, score=0.557 total time=   1.2s
# [CV 1/5] END classifier__C=1, classifier__gamma=0.01;, score=0.550 total time=   1.2s
# [CV 5/5] END classifier__C=1, classifier__gamma=0.01;, score=0.553 total time=   1.2s
# [CV 4/5] END classifier__C=1, classifier__gamma=0.001;, score=0.561 total time=   1.2s
# [CV 3/5] END classifier__C=10, classifier__gamma=1;, score=0.528 total time=   1.4s
# [CV 2/5] END classifier__C=10, classifier__gamma=0.1;, score=0.560 total time=   1.2s
# [CV 1/5] END classifier__C=10, classifier__gamma=0.01;, score=0.563 total time=   1.2s
# [CV 4/5] END classifier__C=10, classifier__gamma=0.01;, score=0.605 total time=   1.2s
# [CV 3/5] END classifier__C=10, classifier__gamma=0.001;, score=0.567 total time=   1.2s
# [CV 2/5] END classifier__C=100, classifier__gamma=1;, score=0.533 total time=   1.4s
# [CV 1/5] END classifier__C=100, classifier__gamma=0.1;, score=0.537 total time=   1.7s
# [CV 5/5] END classifier__C=100, classifier__gamma=0.1;, score=0.556 total time=   1.7s
# [CV 1/5] END classifier__C=100, classifier__gamma=0.001;, score=0.564 total time=   1.2s
# [CV 5/5] END classifier__C=100, classifier__gamma=0.001;, score=0.573 total time=   1.1s
# [CV 2/5] END classifier__C=0.1, classifier__gamma=1;, score=0.123 total time=   1.7s
# [CV 1/5] END classifier__C=0.1, classifier__gamma=0.1;, score=0.116 total time=   1.6s
# [CV 1/5] END classifier__C=0.1, classifier__gamma=0.01;, score=0.131 total time=   1.6s
# [CV 5/5] END classifier__C=0.1, classifier__gamma=0.01;, score=0.155 total time=   1.6s
# [CV 4/5] END classifier__C=0.1, classifier__gamma=0.001;, score=0.110 total time=   1.6s
# [CV 3/5] END classifier__C=1, classifier__gamma=1;, score=0.125 total time=   1.6s
# [CV 2/5] END classifier__C=1, classifier__gamma=0.1;, score=0.163 total time=   1.3s
# [CV 5/5] END classifier__C=1, classifier__gamma=0.1;, score=0.124 total time=   1.3s
# [CV 4/5] END classifier__C=1, classifier__gamma=0.01;, score=0.122 total time=   1.4s
# [CV 3/5] END classifier__C=1, classifier__gamma=0.001;, score=0.124 total time=   1.6s
# [CV 2/5] END classifier__C=10, classifier__gamma=1;, score=0.145 total time=   1.7s
# [CV 1/5] END classifier__C=10, classifier__gamma=0.1;, score=0.107 total time=   1.0s
# [CV 4/5] END classifier__C=10, classifier__gamma=0.1;, score=0.126 total time=   1.0s
# [CV 3/5] END classifier__C=10, classifier__gamma=0.01;, score=0.100 total time=   1.3s
# [CV 2/5] END classifier__C=10, classifier__gamma=0.001;, score=0.126 total time=   1.5s
# [CV 1/5] END classifier__C=100, classifier__gamma=1;, score=0.146 total time=   1.6s
# [CV 5/5] END classifier__C=100, classifier__gamma=1;, score=0.105 total time=   1.6s
# [CV 1/5] END classifier__C=100, classifier__gamma=0.01;, score=0.110 total time=   1.3s
# [CV 5/5] END classifier__C=100, classifier__gamma=0.01;, score=0.152 total time=   1.3s
# [CV 4/5] END classifier__C=100, classifier__gamma=0.001;, score=0.106 total time=   1.3s
# [CV 3/5] END classifier__C=0.1, classifier__gamma=1;, score=0.036 total time=   1.4s
# [CV 1/5] END classifier__C=0.1, classifier__gamma=0.1;, score=0.501 total time=   1.2s
# [CV 5/5] END classifier__C=0.1, classifier__gamma=0.1;, score=0.514 total time=   1.2s
# [CV 4/5] END classifier__C=0.1, classifier__gamma=0.01;, score=0.574 total time=   1.2s
# [CV 3/5] END classifier__C=0.1, classifier__gamma=0.001;, score=0.515 total time=   1.2s
# [CV 2/5] END classifier__C=1, classifier__gamma=1;, score=0.535 total time=   1.3s
# [CV 1/5] END classifier__C=1, classifier__gamma=0.1;, score=0.545 total time=   1.2s
# [CV 5/5] END classifier__C=1, classifier__gamma=0.1;, score=0.585 total time=   1.2s
# [CV 4/5] END classifier__C=1, classifier__gamma=0.01;, score=0.600 total time=   1.2s
# [CV 3/5] END classifier__C=1, classifier__gamma=0.001;, score=0.505 total time=   1.2s
# [CV 2/5] END classifier__C=10, classifier__gamma=1;, score=0.534 total time=   1.4s
# [CV 1/5] END classifier__C=10, classifier__gamma=0.1;, score=0.572 total time=   1.3s
# [CV 5/5] END classifier__C=10, classifier__gamma=0.1;, score=0.574 total time=   1.3s
# [CV 5/5] END classifier__C=10, classifier__gamma=0.01;, score=0.571 total time=   1.2s
# [CV 4/5] END classifier__C=10, classifier__gamma=0.001;, score=0.581 total time=   1.2s
# [CV 3/5] END classifier__C=100, classifier__gamma=1;, score=0.528 total time=   1.4s
# [CV 2/5] END classifier__C=100, classifier__gamma=0.1;, score=0.569 total time=   1.7s
# [CV 1/5] END classifier__C=100, classifier__gamma=0.01;, score=0.551 total time=   1.4s
# [CV 4/5] END classifier__C=100, classifier__gamma=0.01;, score=0.583 total time=   1.4s
# [CV 3/5] END classifier__C=100, classifier__gamma=0.001;, score=0.595 total time=   1.3s
# [CV 1/5] END classifier__C=0.1, classifier__gamma=1;, score=0.129 total time=   1.7s
# [CV 3/5] END classifier__C=0.1, classifier__gamma=0.1;, score=0.101 total time=   1.6s
# [CV 4/5] END classifier__C=0.1, classifier__gamma=0.1;, score=0.091 total time=   1.6s
# [CV 3/5] END classifier__C=0.1, classifier__gamma=0.01;, score=0.117 total time=   1.6s
# [CV 3/5] END classifier__C=0.1, classifier__gamma=0.001;, score=0.109 total time=   1.6s
# [CV 2/5] END classifier__C=1, classifier__gamma=1;, score=0.128 total time=   1.6s
# [CV 1/5] END classifier__C=1, classifier__gamma=0.1;, score=0.124 total time=   1.3s
# [CV 4/5] END classifier__C=1, classifier__gamma=0.1;, score=0.129 total time=   1.2s
# [CV 3/5] END classifier__C=1, classifier__gamma=0.01;, score=0.126 total time=   1.4s
# [CV 2/5] END classifier__C=1, classifier__gamma=0.001;, score=0.140 total time=   1.5s
# [CV 1/5] END classifier__C=10, classifier__gamma=1;, score=0.143 total time=   1.5s
# [CV 5/5] END classifier__C=10, classifier__gamma=1;, score=0.105 total time=   1.6s
# [CV 2/5] END classifier__C=10, classifier__gamma=0.01;, score=0.122 total time=   1.3s
# [CV 1/5] END classifier__C=10, classifier__gamma=0.001;, score=0.138 total time=   1.5s
# [CV 5/5] END classifier__C=10, classifier__gamma=0.001;, score=0.130 total time=   1.5s
# [CV 4/5] END classifier__C=100, classifier__gamma=1;, score=0.161 total time=   1.7s
# [CV 3/5] END classifier__C=100, classifier__gamma=0.1;, score=0.069 total time=   1.0s
# [CV 2/5] END classifier__C=100, classifier__gamma=0.01;, score=0.139 total time=   1.3s
# [CV 1/5] END classifier__C=100, classifier__gamma=0.001;, score=0.117 total time=   1.5s
# [CV 5/5] END classifier__C=100, classifier__gamma=0.001;, score=0.112 total time=   1.2s
# [CV 4/5] END classifier__C=0.1, classifier__gamma=1;, score=0.036 total time=   1.5s
# [CV 3/5] END classifier__C=0.1, classifier__gamma=0.1;, score=0.540 total time=   1.2s
# [CV 2/5] END classifier__C=0.1, classifier__gamma=0.01;, score=0.550 total time=   1.2s
# [CV 1/5] END classifier__C=0.1, classifier__gamma=0.001;, score=0.498 total time=   1.2s
# [CV 5/5] END classifier__C=0.1, classifier__gamma=0.001;, score=0.491 total time=   1.2s
# [CV 4/5] END classifier__C=1, classifier__gamma=1;, score=0.547 total time=   1.3s
# [CV 3/5] END classifier__C=1, classifier__gamma=0.1;, score=0.591 total time=   1.2s
# [CV 2/5] END classifier__C=1, classifier__gamma=0.01;, score=0.586 total time=   1.2s
# [CV 1/5] END classifier__C=1, classifier__gamma=0.001;, score=0.508 total time=   1.2s
# [CV 5/5] END classifier__C=1, classifier__gamma=0.001;, score=0.530 total time=   1.2s
# [CV 4/5] END classifier__C=10, classifier__gamma=1;, score=0.549 total time=   1.4s
# [CV 3/5] END classifier__C=10, classifier__gamma=0.1;, score=0.567 total time=   1.2s
# [CV 2/5] END classifier__C=10, classifier__gamma=0.01;, score=0.554 total time=   1.2s
# [CV 1/5] END classifier__C=10, classifier__gamma=0.001;, score=0.509 total time=   1.2s
# [CV 5/5] END classifier__C=10, classifier__gamma=0.001;, score=0.511 total time=   1.2s
# [CV 4/5] END classifier__C=100, classifier__gamma=1;, score=0.547 total time=   1.4s
# [CV 3/5] END classifier__C=100, classifier__gamma=0.1;, score=0.517 total time=   1.7s
# [CV 2/5] END classifier__C=100, classifier__gamma=0.01;, score=0.533 total time=   1.4s
# [CV 5/5] END classifier__C=100, classifier__gamma=0.01;, score=0.578 total time=   1.4s
# [CV 4/5] END classifier__C=100, classifier__gamma=0.001;, score=0.630 total time=   1.2s
